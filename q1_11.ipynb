# %%
# Q1. Perform elementary mathematical operations in Octave/MATLAB/R/Python like addition, multiplication, division and exponentiation.

#ADDITION____
a=int(input("enter the value of the a: "))
b=int(input("Enter the value of the b: "))
c=a+b
print("The sum of the a and b is ", c)

#MULTIPLICATION____
multiplication= a*b
print("the multiplication of a and b is :", multiplication)

#DIVISION____
division = a/b
print("the division of a and b is :", division)

#EXPONENTIAL____
exponential= b**3
print("the exponential value of b is :", exponential)

e=5**2
print(e)

#==========================================================================

# Q2. Perform elementary logical operations in Octave/MATLAB/R/Python (like OR, AND, Checking for Equality, NOT, XOR).

# AND operation
a = True
b = False
result_and = a and b  # result_and will be False
print("AND Result:", result_and)

# OR operation
a = True
b = False
result_or = a or b  # result_or will be True
print("OR Result:", result_or)

# NOT operation
a = True
result_not = not a  # result_not will be False
print("NOT Result:", result_not)

# XOR operation
a = True
b = False
result_xor = (a != b)  # result_xor will be True
print("XOR Result:(!=)", result_xor)
result_xor = a ^ b  # result_xor will be True
print("XOR Result:(^)", result_xor)

# Equality check
a = 5
b = 7
result_eq = (a == b)  # result_eq will be False
print("Equality Check Result:", result_eq)

#==============================================================================

# Q3. Create, initialize and display simple variables and simple strings and use simple formatting for variable.


# Create and initialize variables
age = 25
name = "John"
height = 175.5

# Display variables
print("Name:", name)
print("Age:", age)
print("Height:", height)

# Use simple formatting for variables
print("\nUsing simple formatting:")
print("Name: %s, Age: %d, Height: %.2f" % (name, age, height))

#========================================================================

# Q4. Create/Define single dimension / multi-dimension arrays, and arrays with specific values like array of all ones, all zeros, array with random values within a range, or a diagonal matrix.

import numpy as np

# Creating single-dimension arrays
x = np.array([1, 2, 3, 4, 5])
print('x = ', x)

y = np.array([[1], [2], [3]])
print('y = \n', y)

# Creating multi-dimension arrays
z = np.array([[1, 2, 3], [6, 7, 8]])
print('z = \n', z)

z1 = np.matrix('1 2 3; 6 7 8')
print('z1 = \n', z1)

# Matrix with all ones
A = np.ones((4, 4))
print(A)

# Matrix with all zeros
B = np.zeros((4, 4))
print(B)

# Matrix with random values within a range
C = np.random.randint(20, 50, (4,5))
print("C = \n", C)

# Matrix with range
C1 = np.arange(12).reshape((3, 4))
print("C1 = \n", C1)

# Diagonal matrix
D = np.diag([1, 2, 3, 4, 5])
print('D = \n', D)

#==========================================================================

# Q5. Use command to compute the size of a matrix, size/length of a particular row/column, load data from a text file, store matrix data to a text file, finding out variables and their features in the current scope.

import numpy as np

A = np.arange(12).reshape((3, 4))
print(A)

# Size of matrix
# A.size
print(np.size(A))

# Shape of matrix
print(A.shape)

# Length of 1st row
len(A[0])

# Length of first column
np.size(A, 0) #---------------o/p

# Loading data from text file
#np.loadtxt("input5.txt", delimiter=',', dtype=int)
import pandas as pd

df = pd.read_csv('input5.txt')
print(df) #----------------o/p

df.drop(df.tail(5).index,inplace=True)
print(df) #---------------o/p

# Saving data to txt file
df.to_csv('output5.txt', sep=' ') #----------o/p

# List of features
df.columns.values #----------o/p

#=========================================================================

# Q6. Perform basic operations on matrices (like addition, subtraction, multiplication) and display specific rows or columns of the matrix.

import numpy as np
A = np.array([[3, 6, 9], [5, -10, 15], [-7, 14, 21]])
B = np.array([[9, -18, 27], [11, 22, 33], [13, -26, 39]])
print("A = \n", A, "\nB = \n", B)

# Matrix Addition
C = A + B
print('C = A + B =\n', C)

# Matrix Subtraction
C = A - B
print('C = A - B =\n', C)

# Matrix Multiplication
C = A.dot(B)
print('C = A * B =\n', C)

# Print 2nd row of Matrix A
print(A[1:2])

# Print 1st row of Matrix B
print(B[:1])

# Print 2nd column of Matrix A
print(A[:,1:2])

# Print 3rd column of Matrix B
print(B[:,2:3])

#======================================================================

# Q7. Perform other matrix operations like converting matrix data to absolute values, taking the negative of matrix values, additing/removing rows/columns from a matrix, finding the maximum or minimum values in a matrix or in a row/column, and finding the sum of some/all elements in a matrix.

import numpy as np
A = np.array([[3, 6, 9], [5, -10, 15], [-7, 14, 21]])
B = np.array([[9, -18, 27], [11, 22, 33], [13, -26, 39]])
print("A = \n", A, "\nB = \n", B)

# Converting matrix A data to its absolute values
print(np.absolute(A))

# Converting matrix B data to its negative values
print(np.negative(B))

# Deleting a row from Matrix A
print(np.delete(A, 1, 0))

# Deleting a column from Matrix B
print(np.delete(B, 0, 1))

# Adding a row to Matrix A
print(np.append(A, np.array([[23, -45, 56]]), axis=0))

# Adding a column to Matrix B
print(np.append(B, [[23], [-45], [56]], axis=1))

# Maximum of 2nd row of Matrix A
print(np.max(A, 0)[1])

# Minimum of 2nd row of Matrix A
print(np.min(A, 0)[1])

# Maximum of 3rd column of Matrix B
print(np.max(B, 1)[2])

# Minimum of 3rd column of Matrix B
print(np.min(B, 1)[2])

# Sum of some elements of array
print(np.sum(A[1:, 1:]))

# Sum of all elements of array
sumA = np.sum(A)
sumB = np.sum(B)
print('sumA = ', sumA, ', sumB = ', sumB)

#========================================================================

# Q8. Create various type of plots/charts like histograms, plot based on sine/cosine function based on data from a matrix. Further label different axes in a plot and data in a plot.

import numpy as np
import matplotlib.pyplot as plt

# Histogram
list = np.array([20, 45, 45, 35, 30, 10, 30, 20, 20, 50, 30, 20, 20, 10, 45, 25, 35])
plt.hist(list)
plt.xlabel('Integer')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show() #----------o/p

import math

# Sine curve
degrees = range(0 , 720)
sinValues = [math.sin(math.radians(i)) for i in degrees]
plt.plot(sinValues)
plt.xlabel('Degrees')
plt.ylabel('Sin Values')
plt.title('Sine Curve')
plt.grid()
plt.show() #----------o/p

# Cosine curve
degrees = range(0 , 720)
sinValues = [math.cos(math.radians(i)) for i in degrees]
plt.plot(sinValues)
plt.xlabel('Degrees')
plt.ylabel('Cosine Values')
plt.title('Cosine Curve')
plt.grid()
plt.show() #----------o/p

#=====================================================================

# Q9. Generate different subplots from a given plot and color plot data.

import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
x = np.arange(0.0, 2.0, 0.01)
y = 1 + np.sin(2 * np.pi * x)

# Creating 6 subplots and unpacking the output array immediately
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
ax1.plot(x, y, color="orange")
ax2.plot(x[3:30], y[3:30], color="green")
ax3.plot(x[30:90], y[30:90], color="blue")
ax4.plot(x[90:150], y[90:150], color="magenta")

#==========================================================================

# Q10. Use conditional statements and different type of loops based on simple example/s.

#if - elif - else
grade = None
marks = 90
if marks >= 95:
    grade = 'A+'
elif marks >= 90:
    grade = 'A'
elif marks >= 80:
    grade = 'B'
elif marks >= 75:
    grade = 'C'
elif marks >= 65:
    grade = 'D'
else:
    grade = 'F'
grade #----------o/p

# while loop
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1 #----------o/p

  # for loop
fruits = ["apple", "cherry", "banana"]
for x in fruits:
  print(x)
  if x == "banana":
    break #----------o/p


#========================================================================

# Q11. Perform vectorized implementation of simple matrix operation like finding the transpose of a matrix, adding, subtracting or multiplying two matrices.

import numpy as np
A = np.array([[3, 6, 9], [5, -10, 15], [-7, 14, 21]])
B = np.array([[9, -18, 27], [11, 22, 33], [13, -26, 39]])
print("A = \n", A, "\nB = \n", B)

# Addition
A + B

# Subtraction
A - B

# Multiplication
A @ B

# Transpose
print("A' = \n", np.transpose(A),
      "\nB' = \n", np.transpose(B))
